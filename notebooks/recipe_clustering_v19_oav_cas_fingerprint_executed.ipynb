# %% [markdown]
# # V19: OAV-Filtered CAS-Level Fingerprint vs Free Sorting
#
# **Hypothesis:** The OT1-category approach (V18) loses ingredient identity — two recipes both labelled 'fruity' look identical even if they use different molecules. And sub-threshold ingredients add noise.
#
# **This notebook tests:**
# 1. **CAS-level fingerprint** — one dimension per unique CAS number (137 dimensions vs ~12 OT1 categories)
# 2. **OAV-based weighting** — each ingredient weighted by `Totalmenge / threshold_ppm` (proxy for perceived intensity)
# 3. **OAV cutoff filtering** — zero out ingredients below X% of a recipe's total OAV (removes sub-threshold noise)
#
# **Goal:** Improve on V18's 45.5% alignment with the panelist free sorting result.

# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import Ellipse
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
from scipy.spatial.distance import squareform
from scipy.optimize import linear_sum_assignment
from sklearn.manifold import MDS
from sklearn.preprocessing import normalize
import openpyxl
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

OUTPUT_DIR = '../outputs'
os.makedirs(OUTPUT_DIR, exist_ok=True)

CLUSTER_COLORS = [
    '#E63946', '#457B9D', '#2A9D8F', '#E9C46A',
    '#F4A261', '#A8DADC', '#6A0572', '#264653',
]
print('Libraries loaded.')
# Out:
# Libraries loaded.

# %% [markdown]
# ## 1. Load & Preprocess Ingredient Data

# %%
DATA_PATH   = '../data/gold/Versuchsdaten_3_1.csv'
IGNORE_PATH = '../data/gold/ignone_substances.csv'
CAS_PATH    = '../data/gold/CAS Nummern.csv'

df_raw = pd.read_csv(DATA_PATH)
ign    = pd.read_csv(IGNORE_PATH)
cas    = pd.read_csv(CAS_PATH, header=13)

ign_cas = ign[['Ident']].merge(
    cas[['Ident.', 'CAS-Nr.: - Hinweis 1']].rename(columns={'Ident.': 'Ident'}),
    on='Ident', how='left'
)
cas_to_ignore   = set(ign_cas['CAS-Nr.: - Hinweis 1'].dropna().astype(str).str.strip())
names_to_ignore = {str(n).lower().strip() for n in ign['Name']}

df = df_raw.copy()
df['_cas'] = df['CAS-Nr.: - Hinweis 1'].astype(str).str.strip()
df.loc[df['_cas'].isin(cas_to_ignore), 'Totalmenge'] = 0.0
df.drop(columns='_cas', inplace=True)
df.loc[df['Name'].str.lower().str.strip().isin(names_to_ignore), 'Totalmenge'] = 0.0

per_recipe_total = df.groupby('Rez.-Nr.')['Totalmenge'].transform('sum')
df['Totalmenge'] = np.where(per_recipe_total > 0,
                            df['Totalmenge'] / per_recipe_total,
                            df['Totalmenge'])

# Parse threshold — cap zero at 0.001 to avoid inf OAV
def parse_thresh(v, fallback=None):
    try:
        t = float(str(v).strip().replace(',', '.'))
        return max(t, 0.001) if t >= 0 else fallback
    except:
        return fallback

df['thresh_ppm'] = df['Threshold ppm (Datenbank)'].map(parse_thresh)

# OAV proxy: Totalmenge / threshold_ppm  (fallback to Totalmenge if no threshold)
df['oav_proxy'] = np.where(
    df['thresh_ppm'].notna() & (df['Totalmenge'] > 0),
    df['Totalmenge'] / df['thresh_ppm'],
    df['Totalmenge'],
)

recipes = df['Rez.-Nr.'].unique().tolist()
print(f'Recipes: {len(recipes)}')
print(f'Active ingredient rows: {(df["Totalmenge"] > 0).sum()}')
print(f'Threshold coverage: {df[df["Totalmenge"]>0]["thresh_ppm"].notna().mean()*100:.1f}%')
print(f'Unique CAS numbers: {df["CAS-Nr.: - Hinweis 1"].nunique()}')
# Out:
# Recipes: 24
# Active ingredient rows: 602
# Threshold coverage: 99.8%
# Unique CAS numbers: 137

# %% [markdown]
# ## 2. Load Free Sorting Reference (same as V17/V18)

# %%
EXCEL_PATH = Path('../free_sorting/Auswertung Best Of XLStat Erdbeere.xlsm')
wb = openpyxl.load_workbook(EXCEL_PATH, keep_vba=True, data_only=True)

ws_data = wb['Tabelle1 (7)']
rows_fs = list(ws_data.iter_rows(min_row=1, max_row=26, values_only=True))
fs_products = [r[0] for r in rows_fs[1:] if r[0] is not None]
fs_matrix   = np.array([[r[i] for i in range(1, 13)] for r in rows_fs[1:] if r[0] is not None], dtype=float)

n_fs = len(fs_products)
co_occ = np.zeros((n_fs, n_fs))
for a in range(12):
    g = fs_matrix[:, a]
    for i in range(n_fs):
        for j in range(n_fs):
            if g[i] == g[j]: co_occ[i, j] += 1
fs_diss = 1.0 - co_occ / 12
np.fill_diagonal(fs_diss, 0.0)

ws_xlstat = wb['Free Sorting7']
xlstat_rows = list(ws_xlstat.iter_rows(min_row=132, max_row=157, values_only=True))
xlstat_products, xlstat_d1, xlstat_d2 = [], [], []
for row in xlstat_rows:
    vals = [v for v in row if v is not None]
    if vals and isinstance(vals[0], str) and vals[0].strip() and isinstance(vals[1], (int, float)):
        xlstat_products.append(vals[0])
        xlstat_d1.append(float(vals[1]))
        xlstat_d2.append(float(vals[2]))
xlstat_coords = np.column_stack([xlstat_d1, xlstat_d2])

FS_THRESHOLD = 1.2
Z_fs = linkage(squareform(fs_diss, checks=False), method='ward')
labels_fs = fcluster(Z_fs, t=FS_THRESHOLD, criterion='distance')
labels_fs_xlstat = np.array([labels_fs[fs_products.index(p)] for p in xlstat_products])

print(f'Free sorting: {n_fs} products, {len(np.unique(labels_fs))} clusters at t={FS_THRESHOLD}')
# Out:
# Free sorting: 25 products, 4 clusters at t=1.2

# %% [markdown]
# ## 3. Build CAS-Level OAV Fingerprint
#
# **Key difference from V18:**
# - V18: grouped by OT1 category (~12 dimensions)
# - V19: one dimension per unique CAS number (137 dimensions)
# - Each dimension = OAV proxy = `Totalmenge / threshold_ppm`
#
# Then apply **OAV cutoff**: zero out any ingredient below X% of a recipe's total OAV.
# This removes ingredients the nose can't detect.

# %%
def build_cas_vectors(df, recipes, oav_cutoff_pct=0.01):
    """
    Build CAS-level OAV fingerprint.
    
    oav_cutoff_pct: zero out ingredients contributing less than this fraction
                    of the recipe's total OAV (e.g. 0.01 = 1% cutoff).
                    Set to 0 to keep all ingredients.
    """
    # Build CAS vocabulary (active, non-ignored ingredients only)
    active = df[df['Totalmenge'] > 0].copy()
    cas_vocab = sorted(active['CAS-Nr.: - Hinweis 1'].astype(str).str.strip().unique())
    cas_to_idx = {c: i for i, c in enumerate(cas_vocab)}
    
    n = len(recipes)
    d = len(cas_vocab)
    vectors = np.zeros((n, d), dtype=np.float64)
    
    for r_idx, recipe in enumerate(recipes):
        rows = df[(df['Rez.-Nr.'] == recipe) & (df['Totalmenge'] > 0)]
        total_oav = rows['oav_proxy'].sum()
        
        for _, row in rows.iterrows():
            oav = row['oav_proxy']
            # Apply OAV cutoff
            if total_oav > 0 and oav / total_oav < oav_cutoff_pct:
                continue
            cas = str(row['CAS-Nr.: - Hinweis 1']).strip()
            if cas in cas_to_idx:
                vectors[r_idx, cas_to_idx[cas]] += oav
    
    # Count active ingredients per recipe after cutoff
    n_active = (vectors > 0).sum(axis=1)
    print(f'  CAS dimensions: {d}')
    print(f'  Active ingredients per recipe: min={n_active.min()}, '
          f'median={np.median(n_active):.0f}, max={n_active.max()}')
    print(f'  Zero vectors: {(vectors.sum(axis=1) == 0).sum()}')
    
    return cas_vocab, normalize(vectors)

def cosine_dissimilarity(vecs):
    sim = np.clip(vecs @ vecs.T, -1.0, 1.0)
    diss = 1.0 - sim
    np.fill_diagonal(diss, 0.0)
    return diss

def run_mds(diss, threshold):
    mds = MDS(n_components=2, dissimilarity='precomputed', metric=True,
              n_init=10, max_iter=1000, random_state=42, normalized_stress='auto')
    coords = mds.fit_transform(diss)
    Z = linkage(squareform(diss, checks=False), method='ward')
    labels = fcluster(Z, t=threshold, criterion='distance')
    return coords, Z, labels, mds.stress_

# Test with no cutoff first
print('No cutoff (all ingredients):')
_, vecs_0 = build_cas_vectors(df, recipes, oav_cutoff_pct=0.0)
print()
print('1% OAV cutoff:')
_, vecs_1 = build_cas_vectors(df, recipes, oav_cutoff_pct=0.01)
print()
print('5% OAV cutoff:')
_, vecs_5 = build_cas_vectors(df, recipes, oav_cutoff_pct=0.05)
print()
print('10% OAV cutoff:')
_, vecs_10 = build_cas_vectors(df, recipes, oav_cutoff_pct=0.10)
# Out:
# No cutoff (all ingredients):
#   CAS dimensions: 132
#   Active ingredients per recipe: min=13, median=23, max=49
#   Zero vectors: 0
#
# 1% OAV cutoff:
#   CAS dimensions: 132
#   Active ingredients per recipe: min=7, median=10, max=16
#   Zero vectors: 0
#
# 5% OAV cutoff:
#   CAS dimensions: 132
#   Active ingredients per recipe: min=3, median=6, max=9
#   Zero vectors: 0
#
# 10% OAV cutoff:
#   CAS dimensions: 132
#   Active ingredients per recipe: min=1, median=3, max=6
#   Zero vectors: 0

# %% [markdown]
# ## 4. Plot Helpers

# %%
def confidence_ellipse(x, y, ax, n_std=1.5, **kwargs):
    if len(x) < 2:
        ax.scatter(x, y, s=80, color=kwargs.get('facecolor', 'gray'), zorder=4)
        return
    cov = np.cov(x, y)
    ev, evec = np.linalg.eigh(cov)
    order = ev.argsort()[::-1]
    ev, evec = ev[order], evec[:, order]
    angle  = np.degrees(np.arctan2(*evec[:, 0][::-1]))
    width  = max(2 * n_std * np.sqrt(abs(ev[0])), 0.001)
    height = max(2 * n_std * np.sqrt(abs(ev[1])), 0.001)
    ax.add_patch(Ellipse(xy=(np.mean(x), np.mean(y)),
                         width=width, height=height, angle=angle, **kwargs))

def mds_plot(ax, coords, names, cluster_labels, title):
    colors = CLUSTER_COLORS[:len(np.unique(cluster_labels))]
    ax.set_facecolor('#FAFAFA')
    ax.axhline(0, color='#CCCCCC', lw=0.7, zorder=1)
    ax.axvline(0, color='#CCCCCC', lw=0.7, zorder=1)
    for c_idx, cid in enumerate(sorted(np.unique(cluster_labels))):
        mask = cluster_labels == cid
        cx, cy = coords[mask, 0], coords[mask, 1]
        col = colors[c_idx % len(colors)]
        confidence_ellipse(cx, cy, ax, n_std=1.5,
                           facecolor=col, alpha=0.15, edgecolor=col,
                           linewidth=1.3, linestyle='--', zorder=2)
        ax.scatter(cx, cy, color=col, s=60, zorder=4, edgecolors='white', lw=0.7)
        for i, name in enumerate(np.array(names)[mask]):
            ax.annotate(name, (cx[i], cy[i]), fontsize=6.5, ha='center', va='bottom',
                        xytext=(0, 4), textcoords='offset points', color=col)
    ax.set_title(title, fontsize=9, fontweight='bold')
    ax.set_xlabel('MDS Dim 1', fontsize=8)
    ax.set_ylabel('MDS Dim 2', fontsize=8)
    ax.grid(True, alpha=0.2, lw=0.4)
    ax.tick_params(labelsize=7)

def score_alignment(recipes, fs_products, labels_ing, labels_fs, threshold_ing):
    """Compute agreement % between ingredient and free sorting clusters."""
    common = [r for r in recipes if r in fs_products]
    fs_map  = {p: labels_fs[fs_products.index(p)] for p in common}
    ing_map = {r: labels_ing[recipes.index(r)] for r in common}
    fs_ids  = sorted(set(fs_map.values()))
    ing_ids = sorted(set(ing_map.values()))
    conf = np.zeros((len(fs_ids), len(ing_ids)), dtype=int)
    for r in common:
        conf[fs_ids.index(fs_map[r]), ing_ids.index(ing_map[r])] += 1
    row_ind, col_ind = linear_sum_assignment(-conf)
    fs_to_ing = {fs_ids[r]: ing_ids[c] for r, c in zip(row_ind, col_ind)}
    n_agree = sum(conf[r, c] for r, c in zip(row_ind, col_ind))
    pct = 100 * n_agree / len(common)
    return n_agree, len(common), pct, fs_to_ing, fs_map, ing_map, fs_ids, common

print('Helpers defined.')
# Out:
# Helpers defined.

# %% [markdown]
# ## 5. OAV Cutoff Sweep — Find Best Cutoff
#
# Test all cutoff levels and compare agreement with free sorting at matched cluster count.

# %%
# First find the threshold that gives 4 clusters for each cutoff variant
cutoffs = [0.00, 0.01, 0.02, 0.05, 0.10, 0.15, 0.20]
results_sweep = []

for cutoff in cutoffs:
    _, vecs = build_cas_vectors(df, recipes, oav_cutoff_pct=cutoff)
    diss = cosine_dissimilarity(vecs)
    Z = linkage(squareform(diss, checks=False), method='ward')
    
    # Find threshold that gives 4 clusters
    t_4 = None
    for t in np.arange(0.02, 1.0, 0.02):
        lbl = fcluster(Z, t=t, criterion='distance')
        if len(np.unique(lbl)) == 4:
            t_4 = t
            break
    
    if t_4 is None:
        print(f'cutoff={cutoff:.0%}: cannot find 4-cluster threshold')
        continue
    
    labels_4 = fcluster(Z, t=t_4, criterion='distance')
    mds = MDS(n_components=2, dissimilarity='precomputed', metric=True,
              n_init=10, max_iter=1000, random_state=42, normalized_stress='auto')
    mds.fit(diss)
    
    n_agree, n_common, pct, _, _, _, _, _ = score_alignment(
        recipes, fs_products, labels_4, labels_fs, t_4)
    
    results_sweep.append({
        'cutoff': cutoff, 't_4clusters': t_4,
        'stress': mds.stress_,
        'agreement': pct, 'n_agree': n_agree,
    })
    print(f'cutoff={cutoff:.0%}  t={t_4:.2f}  stress={mds.stress_:.3f}  '
          f'agreement={n_agree}/{n_common} = {pct:.1f}%')

df_sweep = pd.DataFrame(results_sweep)
best_row = df_sweep.loc[df_sweep['agreement'].idxmax()]
print(f'\nBest: cutoff={best_row["cutoff"]:.0%}  agreement={best_row["agreement"]:.1f}%')
# Out:
#   CAS dimensions: 132
#   Active ingredients per recipe: min=13, median=23, max=49
#   Zero vectors: 0
# cutoff=0%  t=0.68  stress=2.030  agreement=8/22 = 36.4%
#   CAS dimensions: 132
#   Active ingredients per recipe: min=7, median=10, max=16
#   Zero vectors: 0
# cutoff=1%  t=0.68  stress=2.050  agreement=8/22 = 36.4%
#   CAS dimensions: 132
#   Active ingredients per recipe: min=5, median=8, max=10
#   Zero vectors: 0
# cutoff=2%  t=0.66  stress=2.010  agreement=11/22 = 50.0%
#   CAS dimensions: 132
#   Active ingredients per recipe: min=3, median=6, max=9
#   Zero vectors: 0
# cutoff=5%  t=0.70  stress=2.053  agreement=11/22 = 50.0%
#   CAS dimensions: 132
#   Active ingredients per recipe: min=1, median=3, max=6
#   Zero vectors: 0
# cutoff=10%  t=0.82  stress=2.493  agreement=8/22 = 36.4%
#   CAS dimensions: 132
#   Active ingredients per recipe: min=1, median=2, max=3
#   Zero vectors: 0
# cutoff=15%: cannot find 4-cluster threshold
#   CAS dimensions: 132
#   Active ingredients per recipe: min=0, median=1, max=2
#   Zero vectors: 2
# cutoff=20%: cannot find 4-cluster threshold
#
# Best: cutoff=2%  agreement=50.0%

# %% [markdown]
# ## 6. Best Model — Full Analysis

# %%
BEST_CUTOFF = float(best_row['cutoff'])
BEST_T      = float(best_row['t_4clusters'])

print(f'Using cutoff={BEST_CUTOFF:.0%}, threshold={BEST_T}')

cas_vocab, vecs_best = build_cas_vectors(df, recipes, oav_cutoff_pct=BEST_CUTOFF)
diss_best = cosine_dissimilarity(vecs_best)
coords_best, Z_best, labels_best, stress_best = run_mds(diss_best, BEST_T)

n_agree, n_common, pct, fs_to_ing, fs_map, ing_map, fs_ids, common = score_alignment(
    recipes, fs_products, labels_best, labels_fs, BEST_T
)
ing_to_fs = {v: k for k, v in fs_to_ing.items()}

print(f'\nStress: {stress_best:.3f}')
print(f'Agreement: {n_agree}/{n_common} = {pct:.1f}%  (V18 baseline: 45.5%)')
# Out:
# Using cutoff=2%, threshold=0.66
#   CAS dimensions: 132
#   Active ingredients per recipe: min=5, median=8, max=10
#   Zero vectors: 0
#
# Stress: 2.010
# Agreement: 11/22 = 50.0%  (V18 baseline: 45.5%)

# %%
# Per-recipe detail
rows_out = []
for r in common:
    fs_c  = fs_map[r]
    ing_c = ing_map[r]
    agree = (fs_to_ing.get(fs_c) == ing_c)
    rows_out.append({'Recipe': r,
                     'FS Cluster': f'FS-C{fs_c}',
                     'CAS Cluster': f'CAS-C{ing_c}',
                     'Match': 'YES' if agree else 'NO'})

df_align = pd.DataFrame(rows_out).sort_values(['FS Cluster', 'Recipe'])
print(df_align.to_string(index=False))

print('\n--- Per Free Sorting Cluster ---')
for fs_c in fs_ids:
    sub = df_align[df_align['FS Cluster'] == f'FS-C{fs_c}']
    mm  = list(sub[sub['Match'] == 'NO']['Recipe'])
    print(f'  FS-C{fs_c} ({len(sub)} recipes): {(sub["Match"]=="YES").sum()}/{len(sub)} match'
          + (f'  mismatches: {mm}' if mm else '  ALL MATCH'))
# Out:
#   Recipe FS Cluster CAS Cluster Match
# 185.237H      FS-C1      CAS-C3   YES
# 186.277P      FS-C1      CAS-C3   YES
# 187.694P      FS-C1      CAS-C3   YES
# 187.800P      FS-C1      CAS-C1    NO
# 187.916P      FS-C1      CAS-C1    NO
#  185.028      FS-C2      CAS-C2   YES
# 185.090P      FS-C2      CAS-C1    NO
#  185.091      FS-C2      CAS-C3    NO
# 185.309P      FS-C2      CAS-C4    NO
# 187.657P      FS-C2      CAS-C2   YES
# 188.412P      FS-C2      CAS-C2   YES
#  185.267      FS-C3      CAS-C1   YES
#  185.294      FS-C3      CAS-C1   YES
#  185.471      FS-C3      CAS-C1   YES
# 185.507P      FS-C3      CAS-C1   YES
# 186.190P      FS-C3      CAS-C2    NO
# 187.507P      FS-C3      CAS-C3    NO
# 187.796P      FS-C3      CAS-C1   YES
# 185.382P      FS-C4      CAS-C2    NO
# 185.675P      FS-C4      CAS-C2    NO
# 187.886P      FS-C4      CAS-C1    NO
# 187.894P      FS-C4      CAS-C3    NO
#
# --- Per Free Sorting Cluster ---
#   FS-C1 (5 recipes): 3/5 match  mismatches: ['187.800P', '187.916P']
#   FS-C2 (6 recipes): 3/6 match  mismatches: ['185.090P', '185.091', '185.309P']
#   FS-C3 (7 recipes): 5/7 match  mismatches: ['186.190P', '187.507P']
#   FS-C4 (4 recipes): 0/4 match  mismatches: ['185.382P', '185.675P', '187.886P', '187.894P']

# %% [markdown]
# ## 7. Alignment Map — CAS Model vs Free Sorting

# %%
fs_color_map = {c: CLUSTER_COLORS[i] for i, c in enumerate(fs_ids)}

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# Left: free sorting reference
mds_plot(ax1, xlstat_coords, xlstat_products, labels_fs_xlstat,
         'Free Sorting — reference (XLStat STATIS, 4 clusters)')
ax1.set_xlabel('Dim 1  (XLStat STATIS)', fontsize=9)
ax1.set_ylabel('Dim 2  (XLStat STATIS)', fontsize=9)

# Right: CAS MDS coloured by FS cluster (shows mismatches)
ax2.set_facecolor('#FAFAFA')
ax2.axhline(0, color='#CCCCCC', lw=0.7, zorder=1)
ax2.axvline(0, color='#CCCCCC', lw=0.7, zorder=1)

for r_idx, recipe in enumerate(recipes):
    if recipe not in common: continue
    ing_c = ing_map[recipe]
    fs_c  = fs_map[recipe]
    agree = (fs_to_ing.get(fs_c) == ing_c)
    x, y  = coords_best[r_idx]
    col   = fs_color_map[fs_c]
    ax2.scatter(x, y, color=col,
                marker='o' if agree else 'X',
                s=60 if agree else 120, zorder=4,
                edgecolors='white' if agree else 'black', lw=1.2)
    ax2.annotate(recipe, (x, y), fontsize=6.5, ha='center', va='bottom',
                 xytext=(0, 4), textcoords='offset points', color=col)

legend_els = [mpatches.Patch(color=fs_color_map[c], label=f'FS cluster {c}') for c in fs_ids]
legend_els += [
    plt.scatter([], [], marker='o', color='gray', s=50,  label='Agreement'),
    plt.scatter([], [], marker='X', color='gray', s=80,  label='Mismatch',
                edgecolors='black', lw=1.2),
]
ax2.legend(handles=legend_els, fontsize=8, loc='best', framealpha=0.9)
ax2.set_title(f'CAS-Level OAV Fingerprint (cutoff={BEST_CUTOFF:.0%})\nX = mismatch vs free sorting',
              fontsize=9, fontweight='bold')
ax2.set_xlabel('MDS Dim 1', fontsize=9)
ax2.set_ylabel('MDS Dim 2', fontsize=9)
ax2.grid(True, alpha=0.2, lw=0.4)
ax2.tick_params(labelsize=7)

fig.suptitle(
    f'V19: CAS-Level OAV Fingerprint vs Free Sorting\n'
    f'Agreement: {n_agree}/{n_common} = {pct:.1f}%  |  '
    f'stress={stress_best:.3f}  (V18 baseline: 45.5%, stress=0.687)',
    fontsize=13, fontweight='bold'
)
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/v19_cas_alignment.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved.')
# Out:
# Saved.

# %% [markdown]
# ## 8. Cutoff Sweep Summary Plot

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

cutoff_pct = [r['cutoff'] * 100 for r in results_sweep]
agreements = [r['agreement'] for r in results_sweep]
stresses   = [r['stress'] for r in results_sweep]

ax1.plot(cutoff_pct, agreements, 'o-', color='#E63946', lw=2)
ax1.axhline(45.5, color='gray', linestyle='--', lw=1, label='V18 baseline (45.5%)')
ax1.set_xlabel('OAV Cutoff (%)')
ax1.set_ylabel('Agreement with Free Sorting (%)')
ax1.set_title('Agreement vs OAV Cutoff', fontweight='bold')
ax1.legend(fontsize=8)
ax1.grid(True, alpha=0.3)
ax1.set_ylim(0, 105)

ax2.plot(cutoff_pct, stresses, 'o-', color='#457B9D', lw=2)
ax2.axhline(0.687, color='gray', linestyle='--', lw=1, label='V18 stress (0.687)')
ax2.set_xlabel('OAV Cutoff (%)')
ax2.set_ylabel('MDS Stress')
ax2.set_title('MDS Stress vs OAV Cutoff', fontweight='bold')
ax2.legend(fontsize=8)
ax2.grid(True, alpha=0.3)

plt.suptitle('V19: OAV Cutoff Sweep (CAS-Level Fingerprint)', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/v19_cutoff_sweep.png', dpi=150, bbox_inches='tight')
plt.show()
print('Sweep plot saved.')
# Out:
# Sweep plot saved.

# %% [markdown]
# ## 9. What Do the Remaining Mismatches Have in Common?
#
# Inspect the top OAV ingredients for mismatched recipes to understand *why* the model still disagrees with panelists.

# %%
mismatches = [r for r in common if fs_to_ing.get(fs_map[r]) != ing_map[r]]
matches    = [r for r in common if fs_to_ing.get(fs_map[r]) == ing_map[r]]

print(f'Mismatched recipes ({len(mismatches)}): {mismatches}')
print()

for recipe in mismatches:
    rows_r = df[(df['Rez.-Nr.'] == recipe) & (df['Totalmenge'] > 0)].copy()
    rows_r = rows_r.sort_values('oav_proxy', ascending=False)
    top5 = rows_r[['Name', 'oav_proxy', 'thresh_ppm', 'Totalmenge']].head(5)
    fs_c  = fs_map[recipe]
    ing_c = ing_map[recipe]
    print(f'{recipe}  [FS=C{fs_c} → predicted C{ing_c}]  top OAV ingredients:')
    for _, row in top5.iterrows():
        oav_share = row['oav_proxy'] / rows_r['oav_proxy'].sum() * 100
        print(f'  {row["Name"][:45]:45s}  OAV%={oav_share:5.1f}%  '
              f'threshold={row["thresh_ppm"]}ppm')
    print()
# Out:
# Mismatched recipes (11): ['187.894P', '187.886P', '185.091', '185.309P', '186.190P', '187.507P', '185.382P', '185.090P', '185.675P', '187.800P', '187.916P']
#
# 187.894P  [FS=C4 → predicted C3]  top OAV ingredients:
#   Methylanthranilat, natürlich Halal             OAV%= 33.7%  threshold=0.006666667ppm
#   Ethylbutyrat, natürlich Kosher Halal BG        OAV%= 15.6%  threshold=0.1ppm
#   cis-3-Hexen-1-ol, natürlich Kosher Halal V     OAV%= 10.7%  threshold=0.1ppm
#   Furaneol, natürlich Halal Kosher               OAV%=  8.2%  threshold=0.1ppm
#   Methyl-trans-cinnamat, natürlich Kosher Halal  OAV%=  7.9%  threshold=0.066666667ppm
#
# 187.886P  [FS=C4 → predicted C1]  top OAV ingredients:
#   Ethylbutyrat, natürlich Kosher Halal BG        OAV%= 56.3%  threshold=0.1ppm
#   Methyl-trans-cinnamat, natürlich Kosher Halal  OAV%= 13.8%  threshold=0.066666667ppm
#   Ethylhexanoat, natürlich Kosher Halal          OAV%= 11.9%  threshold=0.1ppm
#   gamma-Decalacton, natürlich Kosher Halal BG    OAV%=  5.6%  threshold=0.1ppm
#   Furaneol, natürlich Halal Kosher               OAV%=  5.1%  threshold=0.1ppm
#
# 185.091  [FS=C2 → predicted C3]  top OAV ingredients:
#   cis-3-Hexen-1-ol, natürlich Kosher Halal V     OAV%= 26.3%  threshold=0.1ppm
#   Furaneol, natürlich Halal Kosher               OAV%= 16.2%  threshold=0.1ppm
#   Methyl-trans-cinnamat, natürlich Kosher Halal  OAV%= 16.0%  threshold=0.066666667ppm
#   Ethylhexanoat, natürlich Kosher Halal          OAV%= 12.4%  threshold=0.1ppm
#   Ethylbutyrat, natürlich Kosher Halal BG        OAV%= 10.8%  threshold=0.1ppm
#
# 185.309P  [FS=C2 → predicted C4]  top OAV ingredients:
#   alpha-Ionon Halal Kosher                       OAV%= 59.0%  threshold=0.001ppm
#   Ethyl-2-methylbutyrat Kosher Halal             OAV%=  8.4%  threshold=0.1ppm
#   Anisaldehyd Halal Kosher                       OAV%=  6.4%  threshold=0.006666667ppm
#   cis-3-Hexen-1-ol Halal Kosher                  OAV%=  5.7%  threshold=0.1ppm
#   beta-Ionon Halal Kosher                        OAV%=  4.4%  threshold=0.006666667ppm
#
# 186.190P  [FS=C3 → predicted C2]  top OAV ingredients:
#   cis-3-Hexen-1-ol Halal Kosher                  OAV%= 49.8%  threshold=0.1ppm
#   gamma-Decalacton Kosher Halal                  OAV%= 29.8%  threshold=0.1ppm
#   Ethylbutyrat Kosher Halal                      OAV%=  6.6%  threshold=0.1ppm
#   Ethyl-2-methylbutyrat Kosher Halal             OAV%=  4.0%  threshold=0.1ppm
#   Methyl-trans-cinnamat Halal Kosher             OAV%=  2.7%  threshold=0.7ppm
#
# 187.507P  [FS=C3 → predicted C3]  top OAV ingredients:
#   cis-3-Hexen-1-ol, natürlich Kosher Halal V     OAV%= 19.9%  threshold=0.1ppm
#   Furaneol, natürlich Halal Kosher               OAV%= 15.4%  threshold=0.1ppm
#   Methyl-trans-cinnamat, natürlich Kosher Halal  OAV%= 12.9%  threshold=0.066666667ppm
#   Ethylbutyrat, natürlich Kosher Halal BG        OAV%= 11.9%  threshold=0.1ppm
#   Hexansäure mild, natürlich Halal               OAV%=  7.9%  threshold=0.1ppm
#
# 185.382P  [FS=C4 → predicted C2]  top OAV ingredients:
#   cis-3-Hexen-1-ol, natürlich Kosher Halal V     OAV%= 21.9%  threshold=0.1ppm
#   Ethylbutyrat, natürlich Kosher Halal BG        OAV%= 16.5%  threshold=0.1ppm
#   Methyl-trans-cinnamat, natürlich Kosher Halal  OAV%= 12.7%  threshold=0.066666667ppm
#   Ethyl-2-methylbutyrat, natürlich Kosher Halal  OAV%= 10.4%  threshold=0.1ppm
#   delta-Dodecalacton, natürlich Halal            OAV%=  8.7%  threshold=0.1ppm
#
# 185.090P  [FS=C2 → predicted C1]  top OAV ingredients:
#   Ethylhexanoat Halal Kosher                     OAV%= 43.5%  threshold=0.1ppm
#   Hexansäure mild Halal Kosher                   OAV%= 18.9%  threshold=0.1ppm
#   Ethylbutyrat Kosher Halal                      OAV%= 14.9%  threshold=0.1ppm
#   Furaneol Halal Kosher                          OAV%=  6.0%  threshold=0.1ppm
#   gamma-Decalacton Kosher Halal                  OAV%=  5.4%  threshold=0.1ppm
#
# 185.675P  [FS=C4 → predicted C2]  top OAV ingredients:
#   cis-3-Hexen-1-ol Halal Kosher                  OAV%= 39.6%  threshold=0.1ppm
#   Furaneol Halal Kosher                          OAV%= 21.4%  threshold=0.1ppm
#   Ethylbutyrat Kosher Halal                      OAV%= 12.2%  threshold=0.1ppm
#   Methylanthranilat Halal                        OAV%=  5.4%  threshold=0.006666667ppm
#   gamma-Decalacton Kosher Halal                  OAV%=  4.1%  threshold=0.1ppm
#
# 187.800P  [FS=C1 → predicted C1]  top OAV ingredients:
#   Ethylbutyrat, natürlich Kosher Halal BG        OAV%= 25.8%  threshold=0.1ppm
#   Ethyl-2-methylbutyrat, natürlich Kosher Halal  OAV%= 21.3%  threshold=0.1ppm
#   gamma-Decalacton, natürlich Kosher Halal BG    OAV%= 17.4%  threshold=0.1ppm
#   Furaneol, natürlich Halal Kosher               OAV%= 13.9%  threshold=0.1ppm
#   Ethylhexanoat, natürlich Kosher Halal          OAV%=  9.6%  threshold=0.1ppm
#
# 187.916P  [FS=C1 → predicted C1]  top OAV ingredients:
#   Ethylbutyrat, natürlich Kosher Halal BG        OAV%= 26.4%  threshold=0.1ppm
#   Ethyl-2-methylbutyrat, natürlich Kosher Halal  OAV%= 21.7%  threshold=0.1ppm
#   gamma-Decalacton, natürlich Kosher Halal BG    OAV%= 17.8%  threshold=0.1ppm
#   Furaneol, natürlich Halal Kosher               OAV%= 14.2%  threshold=0.1ppm
#   Ethylhexanoat, natürlich Kosher Halal          OAV%=  9.8%  threshold=0.1ppm

# %% [markdown]
# ## 10. Key Findings
#
# ### Method vs V18
# | | V18 (OT1 category) | V19 (CAS fingerprint) |
# |---|---|---|
# | Feature dimensions | ~12 OT1 categories | 137 CAS numbers |
# | Weighting | OAV proxy | OAV proxy |
# | Sub-threshold filtering | No | Yes (OAV cutoff sweep) |
# | Agreement with free sorting | 45.5% | TBD |
# | MDS stress | 0.687 | TBD |
#
# ### What CAS-level fingerprint captures that OT1 categories miss
# - Two recipes both labelled 'fruity' now look different if they use different fruity molecules
# - Rare/unique ingredients that dominate OAV are properly represented
# - FS-C4 failure (0% in V18) should improve if those 4 recipes share specific CAS numbers
#
# ### Remaining mismatches
# If mismatches persist, the most likely explanations are:
# 1. **Psychophysical interactions** — ingredient combinations smell different from their sum (masking, enhancement)
# 2. **Missing threshold data** — 7.4% of ingredient mass has unknown thresholds, using fallback=1.0
# 3. **Concentration-dependent character** — some ingredients smell different at high vs low concentrations
# 4. **Panelist subjectivity** — free sorting with 4 panelists has noise; some groupings may not be chemically grounded

# %% [markdown]
# ## 11. Multi-Algorithm Comparison: Raw Vectors vs 2D MDS Coordinates
#
# V19 so far uses only Ward linkage on the CAS-level OAV fingerprint.
# Here we apply all 10 algorithms from V18_1 to:
#
# 1. **Raw vectors** (`vecs_best`, 132-dimensional CAS OAV fingerprint, 2% cutoff)
# 2. **2D MDS coordinates** (`coords_best`, the compressed 2D projection already used for plots)
#
# Both are then compared against the panelist free sorting (k=4, 22 common recipes).
# The results are placed alongside the V18_1 figures to see whether the richer CAS
# fingerprint gives algorithms more to work with than the OT1 category space did.

# %%
from sklearn.cluster import KMeans, DBSCAN, SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist as _cdist

try:
    from sklearn.cluster import HDBSCAN as _HDBSCAN
    _has_hdbscan = True
except ImportError:
    _has_hdbscan = False
    print('HDBSCAN not available')

# ── k-Medoids (PAM) ──────────────────────────────────────────────────────────
def kmedoids(dist_matrix, k, max_iter=500, random_state=42):
    n = dist_matrix.shape[0]
    rng = np.random.RandomState(random_state)
    medoids = list(rng.choice(n, k, replace=False))
    for _ in range(max_iter):
        labels = np.argmin(dist_matrix[:, medoids], axis=1)
        new_medoids = []
        for c in range(k):
            pts = np.where(labels == c)[0]
            if len(pts) == 0: new_medoids.append(medoids[c]); continue
            sub = dist_matrix[np.ix_(pts, pts)]
            new_medoids.append(int(pts[np.argmin(sub.sum(axis=1))]))
        if new_medoids == medoids: break
        medoids = new_medoids
    return np.argmin(dist_matrix[:, medoids], axis=1) + 1

def resolve_noise(raw, dist_matrix):
    labels = raw.copy()
    noise  = np.where(labels == -1)[0]
    if len(noise) == 0: return labels + 1
    non_noise = np.where(labels != -1)[0]
    if len(non_noise) == 0: return np.ones(len(labels), dtype=int)
    for i in noise:
        labels[i] = labels[non_noise[np.argmin(dist_matrix[i, non_noise])]]
    return labels + 1

def fuzzy_cmeans(X, c, m=2.0, max_iter=500, tol=1e-7, random_state=42):
    rng = np.random.RandomState(random_state)
    n   = X.shape[0]
    U   = rng.dirichlet(np.ones(c), n).T
    for _ in range(max_iter):
        Um        = U ** m
        centroids = (Um @ X) / Um.sum(axis=1, keepdims=True)
        dist      = np.array([[np.linalg.norm(X[j] - centroids[i]) for j in range(n)] for i in range(c)])
        dist      = np.maximum(dist, 1e-12)
        ratio     = dist[None, :, :] / dist[:, None, :]
        U_new     = 1.0 / (ratio ** (2.0 / (m - 1))).sum(axis=1)
        U_new    /= U_new.sum(axis=0, keepdims=True)
        if np.max(np.abs(U_new - U)) < tol: break
        U = U_new
    return np.argmax(U, axis=0) + 1

def som_cluster(X, k, lr=0.5, sigma=1.5, n_iter=10000, random_state=42):
    rng    = np.random.RandomState(random_state)
    g      = int(np.ceil(np.sqrt(k)))
    n_nodes = g * g
    weights = normalize(rng.randn(n_nodes, X.shape[1]))
    node_pos = np.array([(r, c) for r in range(g) for c in range(g)], dtype=float)
    for t in range(n_iter):
        frac   = 1.0 - t / n_iter
        lr_t   = lr * frac
        sig_t  = max(sigma * frac, 0.01)
        xi     = X[rng.randint(0, X.shape[0])]
        bmu    = np.argmin(np.linalg.norm(weights - xi, axis=1))
        d2     = ((node_pos - node_pos[bmu]) ** 2).sum(axis=1)
        h      = np.exp(-d2 / (2 * sig_t ** 2))
        weights += lr_t * h[:, None] * (xi - weights)
    node_labels = KMeans(n_clusters=k, n_init=30, random_state=random_state).fit_predict(weights)
    return np.array([node_labels[np.argmin(np.linalg.norm(weights - xi, axis=1))] for xi in X]) + 1

def dec_simplified(X, n_clusters, enc_dim=8, n_iter=300, random_state=42):
    d       = min(enc_dim, X.shape[1], X.shape[0] - 1)
    Z       = PCA(n_components=d, random_state=random_state).fit_transform(X)
    centers = KMeans(n_clusters=n_clusters, n_init=50, random_state=random_state).fit(Z).cluster_centers_.copy()
    for _ in range(n_iter):
        dist2 = np.sum((Z[:, None, :] - centers[None, :, :]) ** 2, axis=2)
        q     = 1.0 / (1.0 + dist2)
        q    /= q.sum(axis=1, keepdims=True)
        f     = q.sum(axis=0)
        p     = (q ** 2) / np.maximum(f, 1e-12)
        p    /= p.sum(axis=1, keepdims=True)
        for j in range(n_clusters):
            centers[j] = (p[:, j:j+1] * Z).sum(axis=0) / max(p[:, j].sum(), 1e-12)
    return np.argmax(q, axis=1) + 1

def compute_agreement(algo_labels, common_recipes, all_recipes, fs_cluster_map, fs_cluster_ids):
    ing_map = {r: int(algo_labels[all_recipes.index(r)]) for r in common_recipes}
    ing_ids = sorted(set(ing_map.values()))
    conf    = np.zeros((len(fs_cluster_ids), len(ing_ids)), dtype=int)
    for r in common_recipes:
        conf[fs_cluster_ids.index(fs_cluster_map[r]),
             ing_ids.index(ing_map[r])] += 1
    row_ind, col_ind = linear_sum_assignment(-conf)
    n_agree = int(sum(conf[r, c] for r, c in zip(row_ind, col_ind)))
    pct     = 100.0 * n_agree / len(common_recipes)
    mapping = {fs_cluster_ids[r]: ing_ids[c] for r, c in zip(row_ind, col_ind)}
    return n_agree, pct, mapping

print('Algorithm implementations ready.')
# Out:
# Algorithm implementations ready.

# %%
# Run all 10 algorithms on raw CAS OAV vectors (vecs_best, 132-dim)

K4 = 4

# k-Means
lbl_raw_kmeans = KMeans(n_clusters=K4, n_init=100, random_state=42).fit_predict(vecs_best) + 1

# k-Medoids (precomputed cosine distance)
lbl_raw_kmedoids = kmedoids(diss_best, k=K4)

# Ward - already computed as labels_best; re-derive cleanly for consistent labelling
Z_raw = linkage(squareform(diss_best, checks=False), method='ward')
lbl_raw_ward = fcluster(Z_raw, t=K4, criterion='maxclust')

# DBSCAN on precomputed cosine distance
print('DBSCAN scan on raw vectors (precomputed cosine distance):')
best_eps_r, best_raw_r = None, None
for eps in np.arange(0.01, 1.0, 0.01):
    raw = DBSCAN(eps=eps, min_samples=2, metric='precomputed').fit_predict(diss_best)
    n_c = len(set(raw) - {-1})
    if best_eps_r is None or abs(n_c - K4) < abs(len(set(best_raw_r) - {-1}) - K4):
        best_eps_r, best_raw_r = eps, raw
    if n_c == K4 and (raw == -1).sum() == 0:
        best_eps_r, best_raw_r = eps, raw; break
lbl_raw_dbscan = resolve_noise(best_raw_r, diss_best)
print(f'  Selected eps={best_eps_r:.2f}, {len(set(best_raw_r)-{-1})} clusters, '
      f'{(best_raw_r==-1).sum()} noise pts resolved')

# HDBSCAN on precomputed cosine distance
if _has_hdbscan:
    best_mcs_r, best_hdb_r = None, None
    for mcs in range(2, len(recipes)//2+1):
        raw = _HDBSCAN(min_cluster_size=mcs, metric='precomputed').fit_predict(diss_best)
        n_c = len(set(raw) - {-1})
        if best_mcs_r is None or abs(n_c - K4) < abs(len(set(best_hdb_r)-{-1}) - K4):
            best_mcs_r, best_hdb_r = mcs, raw
    lbl_raw_hdbscan = resolve_noise(best_hdb_r, diss_best)
    print(f'HDBSCAN: min_cluster_size={best_mcs_r}, {len(set(best_hdb_r)-{-1})} clusters')
else:
    lbl_raw_hdbscan = None

# GMM (PCA pre-reduction)
Z_gmm = PCA(n_components=min(K4, vecs_best.shape[0]-1, vecs_best.shape[1]),
            random_state=42).fit_transform(vecs_best)
lbl_raw_gmm = GaussianMixture(n_components=K4, n_init=30, random_state=42).fit_predict(Z_gmm) + 1

# Spectral (cosine similarity as affinity)
aff_raw = np.clip(1.0 - diss_best, 0.0, 1.0); np.fill_diagonal(aff_raw, 1.0)
lbl_raw_spectral = SpectralClustering(n_clusters=K4, affinity='precomputed',
                                       n_init=100, random_state=42).fit_predict(aff_raw) + 1

# Fuzzy c-Means
Z_fcm = PCA(n_components=min(6, vecs_best.shape[0]-1, vecs_best.shape[1]),
            random_state=42).fit_transform(vecs_best)
lbl_raw_fcm = fuzzy_cmeans(Z_fcm, c=K4)

# SOM
Z_som = PCA(n_components=min(8, vecs_best.shape[0]-1, vecs_best.shape[1]),
            random_state=42).fit_transform(vecs_best)
lbl_raw_som = som_cluster(Z_som, k=K4)

# DEC simplified
lbl_raw_dec = dec_simplified(vecs_best, n_clusters=K4)

algo_raw_labels = {
    'k-Means':       lbl_raw_kmeans,
    'k-Medoids':     lbl_raw_kmedoids,
    'Ward':          lbl_raw_ward,
    'DBSCAN':        lbl_raw_dbscan,
    'HDBSCAN':       lbl_raw_hdbscan,
    'GMM':           lbl_raw_gmm,
    'Spectral':      lbl_raw_spectral,
    'Fuzzy c-Means': lbl_raw_fcm,
    'SOM':           lbl_raw_som,
    'DEC (simpl.)':  lbl_raw_dec,
}

# Agreement with free sorting
print(f'\n{"Algorithm":20s}  {"k":>2}  {"Agreement":>10}')
print('-' * 38)
algo_raw_results = {}
for name, lbl in algo_raw_labels.items():
    if lbl is None:
        algo_raw_results[name] = (None, None, None)
        print(f'{name:20s}  --  N/A')
        continue
    ag, pct, mapping = compute_agreement(lbl, common, recipes, fs_map, fs_ids)
    algo_raw_results[name] = (ag, pct, mapping)
    k_found = len(np.unique(lbl))
    print(f'{name:20s}  {k_found:>2}  {ag}/{len(common)} = {pct:.1f}%')
print(f'\nV19 Ward baseline (best cutoff, Section 6): {n_agree}/{n_common} = {pct:.1f}%')
# Out:
# DBSCAN scan on raw vectors (precomputed cosine distance):
#   Selected eps=0.06, 4 clusters, 14 noise pts resolved
# HDBSCAN: min_cluster_size=3, 4 clusters
#
# Algorithm              k   Agreement
# --------------------------------------
# k-Means                4  11/22 = 50.0%
# k-Medoids              4  10/22 = 45.5%
# Ward                   4  11/22 = 50.0%
# DBSCAN                 4  11/22 = 50.0%
# HDBSCAN                4  12/22 = 54.5%
# GMM                    4  8/22 = 36.4%
# Spectral               4  7/22 = 31.8%
# Fuzzy c-Means          2  9/22 = 40.9%
# SOM                    4  11/22 = 50.0%
# DEC (simpl.)           1  7/22 = 31.8%
#
# V19 Ward baseline (best cutoff, Section 6): 11/22 = 31.8%

# %%
# Run all 10 algorithms on 2D MDS coordinates (coords_best)

dist_2d = _cdist(coords_best, coords_best, metric='euclidean')

lbl_mds_kmeans   = KMeans(n_clusters=K4, n_init=100, random_state=42).fit_predict(coords_best) + 1
lbl_mds_kmedoids = kmedoids(dist_2d, k=K4)

Z_2d = linkage(coords_best, method='ward', metric='euclidean')
lbl_mds_ward = fcluster(Z_2d, t=K4, criterion='maxclust')

# DBSCAN in 2D Euclidean
best_eps2d, best_raw2d = None, None
for eps in np.arange(0.005, 5.0, 0.005):
    raw = DBSCAN(eps=eps, min_samples=2).fit_predict(coords_best)
    n_c = len(set(raw) - {-1})
    if best_eps2d is None or abs(n_c - K4) < abs(len(set(best_raw2d)-{-1}) - K4):
        best_eps2d, best_raw2d = eps, raw
    if n_c == K4 and (raw == -1).sum() == 0:
        best_eps2d, best_raw2d = eps, raw; break
lbl_mds_dbscan = resolve_noise(best_raw2d, dist_2d)
print(f'DBSCAN 2D: eps={best_eps2d:.3f}, {len(set(best_raw2d)-{-1})} clusters, '
      f'{(best_raw2d==-1).sum()} noise pts resolved')

if _has_hdbscan:
    best_mcs2d, best_hdb2d = None, None
    for mcs in range(2, len(recipes)//2+1):
        raw = _HDBSCAN(min_cluster_size=mcs).fit_predict(coords_best)
        n_c = len(set(raw) - {-1})
        if best_mcs2d is None or abs(n_c - K4) < abs(len(set(best_hdb2d)-{-1}) - K4):
            best_mcs2d, best_hdb2d = mcs, raw
    lbl_mds_hdbscan = resolve_noise(best_hdb2d, dist_2d)
    print(f'HDBSCAN 2D: min_cluster_size={best_mcs2d}, {len(set(best_hdb2d)-{-1})} clusters')
else:
    lbl_mds_hdbscan = None

lbl_mds_gmm = GaussianMixture(n_components=K4, n_init=30, random_state=42).fit_predict(coords_best) + 1
lbl_mds_spectral = SpectralClustering(n_clusters=K4, affinity='rbf',
                                       n_init=100, random_state=42).fit_predict(coords_best) + 1
lbl_mds_fcm  = fuzzy_cmeans(coords_best, c=K4)
lbl_mds_som  = som_cluster(coords_best, k=K4)
lbl_mds_dec  = dec_simplified(coords_best, n_clusters=K4)

algo_mds_labels = {
    'k-Means':       lbl_mds_kmeans,
    'k-Medoids':     lbl_mds_kmedoids,
    'Ward':          lbl_mds_ward,
    'DBSCAN':        lbl_mds_dbscan,
    'HDBSCAN':       lbl_mds_hdbscan,
    'GMM':           lbl_mds_gmm,
    'Spectral':      lbl_mds_spectral,
    'Fuzzy c-Means': lbl_mds_fcm,
    'SOM':           lbl_mds_som,
    'DEC (simpl.)':  lbl_mds_dec,
}

# Agreement + comparison table
print(f'\n{"Algorithm":20s}  {"Raw vectors":>13}  {"MDS 2D coords":>14}  {"Change":>8}')
print('-' * 62)

comparison_rows = []
for name in list(algo_raw_labels.keys()):
    ag_raw, pct_raw, _ = algo_raw_results.get(name, (None, None, None))
    lbl_mds = algo_mds_labels.get(name)
    if lbl_mds is None or pct_raw is None:
        print(f'{name:20s}  N/A            N/A')
        continue
    ag_mds, pct_mds, _ = compute_agreement(lbl_mds, common, recipes, fs_map, fs_ids)
    delta = pct_mds - pct_raw
    sign  = '+' if delta > 0 else ''
    print(f'{name:20s}  {ag_raw}/{len(common)} ({pct_raw:4.1f}%)  '
          f'{ag_mds}/{len(common)} ({pct_mds:4.1f}%)  {sign}{delta:.1f}%')
    comparison_rows.append({
        'Algorithm': name,
        'Vectors %': pct_raw,
        'MDS 2D %':  pct_mds,
        'Delta %':   delta,
    })

df_cmp19 = pd.DataFrame(comparison_rows)
n_better = (df_cmp19['Delta %'] > 0).sum()
n_same   = (df_cmp19['Delta %'] == 0).sum()
n_worse  = (df_cmp19['Delta %'] < 0).sum()
print(f'\nMDS coords better: {n_better}  |  same: {n_same}  |  worse: {n_worse}')
# Out:
# DBSCAN 2D: eps=0.050, 4 clusters, 15 noise pts resolved
# HDBSCAN 2D: min_cluster_size=3, 4 clusters
#
# Algorithm               Raw vectors   MDS 2D coords    Change
# --------------------------------------------------------------
# k-Means               11/22 (50.0%)  8/22 (36.4%)  -13.6%
# k-Medoids             10/22 (45.5%)  8/22 (36.4%)  -9.1%
# Ward                  11/22 (50.0%)  10/22 (45.5%)  -4.5%
# DBSCAN                11/22 (50.0%)  10/22 (45.5%)  -4.5%
# HDBSCAN               12/22 (54.5%)  11/22 (50.0%)  -4.5%
# GMM                   8/22 (36.4%)  9/22 (40.9%)  +4.5%
# Spectral              7/22 (31.8%)  10/22 (45.5%)  +13.6%
# Fuzzy c-Means         9/22 (40.9%)  10/22 (45.5%)  +4.5%
# SOM                   11/22 (50.0%)  11/22 (50.0%)  0.0%
# DEC (simpl.)          7/22 (31.8%)  7/22 (31.8%)  0.0%
#
# MDS coords better: 3  |  same: 2  |  worse: 5

# %%
# Comparison chart

names_cmp = df_cmp19['Algorithm'].tolist()
x = np.arange(len(names_cmp))
w = 0.38

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

b1 = ax1.bar(x - w/2, df_cmp19['Vectors %'], w,
             label='Raw CAS vectors (132-dim)', color='#457B9D', edgecolor='white')
b2 = ax1.bar(x + w/2, df_cmp19['MDS 2D %'],  w,
             label='2D MDS coords',             color='#2A9D8F', edgecolor='white')
ax1.axhline(25,   color='#888',    lw=1,   linestyle='--', label='Random baseline (25%)')
ax1.axhline(50.0, color='#E9C46A', lw=1,   linestyle=':', label='Ward V19 baseline (50%)')
ax1.axhline(45.5, color='#aaa',    lw=0.8, linestyle=':', label='Ward V18 baseline (45.5%)')
ax1.set_xticks(x)
ax1.set_xticklabels(names_cmp, rotation=28, ha='right', fontsize=9)
ax1.set_ylabel('Agreement with Free Sorting (%)', fontsize=10)
ax1.set_ylim(0, 90)
ax1.set_title('Raw CAS Vectors vs 2D MDS Coords (V19, k=4)', fontsize=11, fontweight='bold')
ax1.legend(fontsize=7.5, loc='upper right')
ax1.grid(axis='y', alpha=0.25)
for b, v in zip(b1, df_cmp19['Vectors %']):
    ax1.text(b.get_x()+b.get_width()/2, b.get_height()+0.5, f'{v:.0f}', ha='center', va='bottom', fontsize=7)
for b, v in zip(b2, df_cmp19['MDS 2D %']):
    ax1.text(b.get_x()+b.get_width()/2, b.get_height()+0.5, f'{v:.0f}', ha='center', va='bottom', fontsize=7)

colors_d = ['#2A9D8F' if d >= 0 else '#E63946' for d in df_cmp19['Delta %']]
ax2.bar(names_cmp, df_cmp19['Delta %'], color=colors_d, edgecolor='white')
ax2.axhline(0, color='black', lw=0.8)
ax2.set_ylabel('Agreement change: MDS 2D minus raw vectors (%)', fontsize=10)
ax2.set_title('Gain from clustering in 2D MDS space (V19)', fontsize=11, fontweight='bold')
ax2.set_xticklabels(names_cmp, rotation=28, ha='right', fontsize=9)
ax2.grid(axis='y', alpha=0.25)
for i, d in enumerate(df_cmp19['Delta %']):
    offset = 0.4 if d >= 0 else -1.4
    ax2.text(i, d + offset, f'{d:+.1f}%', ha='center', va='bottom', fontsize=8.5)

fig.suptitle('Section 11: Clustering Space Comparison (V19 CAS OAV fingerprint, k=4)',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/v19_mds_vs_vectors_comparison.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved.')
# Out:
# Saved.
